# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
from scipy.stats import norm

# %matplotlib inline

# %%
data = [2, 8, 10, 3, 1, 8, 6, 9, 11, 1]

# %%
(np.std(data) * np.sqrt(len(data)) / np.sqrt(len(data) - 1)).round(1)
# Out:
# 3.8

# %%
np.mean(data)
# Out:
# 5.9

# %%
data1 = np.sort('7   11     3     5   10   12   11     9     6     1     8   11     1     4     9'.split()).astype(float)

# %%
np.median(data1)
# Out:
# 8.0

# %%
data1.max() - data1.min()
# Out:
# 11.0

# %%
data1
# Out:
# array([ 1.,  1., 10., 11., 11., 11., 12.,  3.,  4.,  5.,  6.,  7.,  8.,
#         9.,  9.])

# %%
np.percentile(data1, 75)
# Out:
# 10.5

# %%
df = pd.read_csv('bookings.csv', sep=';', parse_dates=['arrival full date'])

# %%
np.cov(list(map(float, '2 10 5 4 7 7 1 4 7 8 6 6 6 7 10'.split())), 
            y=list(map(float, '3 4 7 11 2 11 11 8 8 1 2 2 8 5 9'.split())))
# Out:
# array([[ 6.42857143, -2.28571429],
#        [-2.28571429, 13.12380952]])

# %%
df
# Out:
#                Hotel  Is Canceled  Lead Time arrival full date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         Arrival Date Year Arrival Date Month  Arrival Date Week Number  \
# 0                    2015               July                        27
# ...

# %%
mu, sigma = df['Arrival Date Day of Month'].mean(), np.std(df['Arrival Date Day of Month'])
s = np.random.normal(mu, sigma, 1)

# %%
x = np.linspace(df['Arrival Date Day of Month'].min(),df['Arrival Date Day of Month'].max()
                ,200)

#Creating a Function.
def normal_dist(x , mean , sd):
    prob_density = (np.pi*sd) * np.exp(-0.5*((x-mean)/sd)**2)
    return prob_density

#Calculate mean and Standard deviation.
mean = np.mean(df['Arrival Date Day of Month'])
sd = np.std(df['Arrival Date Day of Month'])

#Apply function to the data.
pdf = normal_dist(x,mean,sd)

#Plotting the Results
plt.pyplot.plot(x,pdf , color = 'red')
plt.pyplot.xlabel('Data points')
plt.pyplot.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
df
# Out:
#                Hotel  Is Canceled  Lead Time arrival full date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         Arrival Date Year Arrival Date Month  Arrival Date Week Number  \
# 0                    2015               July                        27
# ...

# %%
df.groupby('Hotel', as_index=False).agg({'arrival full date': 'min'})
# Out:
#           Hotel arrival full date
# 0    City Hotel        2015-07-01
# 1  Resort Hotel        2015-07-01

# %%
df.query("Hotel == 'City Hotel'")
# Out:
#              Hotel  Is Canceled  Lead Time arrival full date  \
# 40060   City Hotel            0          6        2015-07-01
# 40061   City Hotel            1         88        2015-07-01
# 40062   City Hotel            1         65        2015-07-01
# 40063   City Hotel            1         92        2015-07-01
# 40064   City Hotel            1        100        2015-07-02
# ...            ...          ...        ...               ...
# 119385  City Hotel            0         23        2017-08-30
# 119386  City Hotel            0        102        2017-08-31
# 119387  City Hotel            0         34        2017-08-31
# 119388  City Hotel            0        109        2017-08-31
# 119389  City Hotel            0        205        2017-08-29
#
#         Arrival Date Year Arrival Date Month  Arrival Date Week Number  \
# 40060                2015               July                        27
# 40061                2015               July                        27
# ...

# %%
df['arrival full date'].min().year
# Out:
# 2015

# %%
df = df.rename(columns={'arrival full date': 'full_date'})

# %%
df
# Out:
#                Hotel  Is Canceled  Lead Time  full_date  Arrival Date Year  \
# 0       Resort Hotel            0        342 2015-07-01               2015
# 1       Resort Hotel            0        737 2015-07-01               2015
# 2       Resort Hotel            0          7 2015-07-01               2015
# 3       Resort Hotel            0         13 2015-07-01               2015
# 4       Resort Hotel            0         14 2015-07-01               2015
# ...              ...          ...        ...        ...                ...
# 119385    City Hotel            0         23 2017-08-30               2017
# 119386    City Hotel            0        102 2017-08-31               2017
# 119387    City Hotel            0         34 2017-08-31               2017
# 119388    City Hotel            0        109 2017-08-31               2017
# 119389    City Hotel            0        205 2017-08-29               2017
#
#        Arrival Date Month  Arrival Date Week Number  \
# ...

# %%
def is_2015(dates):
    return dates.year == 2015

# %%
a = pd.DataFrame(df.full_date)

# %%
df['is_2015'] = np.where(df.full_date.dt.year == 2015, 1, 0)

# %%
df
# Out:
#                Hotel  Is Canceled  Lead Time  full_date  Arrival Date Year  \
# 0       Resort Hotel            0        342 2015-07-01               2015
# 1       Resort Hotel            0        737 2015-07-01               2015
# 2       Resort Hotel            0          7 2015-07-01               2015
# 3       Resort Hotel            0         13 2015-07-01               2015
# 4       Resort Hotel            0         14 2015-07-01               2015
# ...              ...          ...        ...        ...                ...
# 119385    City Hotel            0         23 2017-08-30               2017
# 119386    City Hotel            0        102 2017-08-31               2017
# 119387    City Hotel            0         34 2017-08-31               2017
# 119388    City Hotel            0        109 2017-08-31               2017
# 119389    City Hotel            0        205 2017-08-29               2017
#
#        Arrival Date Month  Arrival Date Week Number  \
# ...
